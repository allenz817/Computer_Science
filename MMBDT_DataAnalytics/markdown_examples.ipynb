# %% [markdown]
# # Markdown -- Examples
#
# Here are the examples of using Markdown in Jupyter Notebook.
# You can double-click the following cells to see the markups
# and press the "Run" button to render the output.

# %% [markdown]
# ## Headings

# %% [markdown]
# # Heading1
# ## Heading2
# ### Heading3
# #### Heading4
# ##### Heading5
# ###### Heading6

# %% [markdown]
# ## Ordered Lists

# %% [markdown]
# 1. item1
# 2. item2
#     1. item2.1
#     2. item2.2
# 3. item3

# %% [markdown]
# ## Unordered Lists

# %% [markdown]
# - item1
# - item2
#     - item2.1
#     - item2.2
# - item3

# %% [markdown]
# ## Line Break

# %% [markdown]
# This is the 1st sentence.
# This is the 2nd sentence.

# %% [markdown]
# ## Italic & Bold

# %% [markdown]
# *italics*
# **bold**
# ***italic & bold***

# %% [markdown]
# ## Strikethrough

# %% [markdown]
# ~~~deleted~~~

# %% [markdown]
# ## Blockquote

# %% [markdown]
# >This is a blockquote.

# %% [markdown]
# >This is a nested blockquote
# >> This is a quote in quote

# %% [markdown]
# ## Paragraph

# %% [markdown]
# This is a paragraph.
# This is the second sentence of the 1st paragraph.
#
# This is another paragraph.

# %% [markdown]
# ## Horizontal Line

# %% [markdown]
# ---
# ***
# ___

# %% [markdown]
# ## Hyperlink

# %% [markdown]
# https://www.cse.ust.hk
#
# [HKUST](https://www.cse.ust.hk)

# %% [markdown]
# ### Code

# %% [markdown]
# To print a string in python: `print("Hello world!")`
#
# Here is a function:
# ```
# def fun():
#     print("Hello world!")
# ```
# Here is a function with syntax highlighting:
# ```python
# def fun():
#     print("Hello world!")
# ```

# %% [markdown]
# ### Table

# %% [markdown]
# |Header1|Header2|Header3|
# |-------|-------|-------|
# |cell11 |cell12 |cell13 |
# |cell21 |cell22 |cell23 |
# |cell31 |cell32 |cell33 |

# %% [markdown]
# ### Graphics

# %% [markdown]
# ![](https://www.cse.ust.hk/assets/img/logo-group.png)

# %% [markdown]
# ### Equations

# %% [markdown]
# #### In-line

# %% [markdown]
# The similarity can be calculated by $S(x, y) = \sum_{i=0}^{n} w_i S_i(x, y)$

# %% [markdown]
# #### Block

# %% [markdown]
# The similarity can be calculated by $$S(x, y) = \sum_{i=0}^{n} w_i S_i(x, y)$$
