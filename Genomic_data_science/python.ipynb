# %%
mydna = 'acgt'
mydna = mydna + mydna
mydna
# Out:
# 'acgtacgt'

# %%
dna='atgctggggact'
dna[:3]
dna
# Out:
# 'atgctggggact'

# %%
o1 = dna.find('atg')
dna.find('atg',o1+1)
# Out:
# -1

# %%
seq = 'abcdef'
for i in range(len(seq)+1) :     # line 1
        for j in range(i) :        # line 2
                print(seq[j:i])     # line 3
# Out:
# a
# ab
# b
# abc
# bc
# c
# abcd
# bcd
# cd
# d
# abcde
# bcde
# cde
# de
# e
# abcdef
# bcdef
# cdef
# def
# ef
# f
